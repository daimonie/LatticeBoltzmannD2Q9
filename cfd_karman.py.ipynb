# %%
import numpy as np
from karman import karmanVortexSheet
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.animation import FuncAnimation

# %%
re = 250

numSteps = 10000
numSnap = int(numSteps/1000);

# %%
finegrain = 1
Karman = karmanVortexSheet(re, int(500*finegrain), int(200*finegrain))

Karman.initialise()
Karman.geometry ()

# %%
for time in range(numSteps):
    speed, density = Karman.evolve()
    #print("Iteration %d, elapsed time %.3f" % (time, Karman.report_time ()))
    if time%numSnap == 0: 
        fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True,  figsize=(20, 10))
        plt.subplot(121)
        plt.imshow(speed.transpose(), cmap=cm.Spectral)
        
        plt.subplot(122)
        plt.imshow(density.transpose(), cmap=cm.Spectral)
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title("Cylindrical Karman, Re = %.3f, iteration %d" % (Karman.reynolds, time))
        plt.show();
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-877ef50331f7> in <module>()
#      12         plt.ylabel("y")
#      13         plt.title("Cylindrical Karman, Re = %.3f, iteration %d" % (Karman.reynolds, time))
# ---> 14         plt.show();
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# ...
