# %%
import numpy as np
from tube_constriction import tubeConstriction
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.animation import FuncAnimation
from numba import jit

# %%
re = 500

numSteps = 250000
numSnap = 100;

# %%
finegrain = .01

width = int(finegrain * 1000)
height = int(finegrain * 100)

# %%
tube = tubeConstriction(re, width, height, height/9)

tube.initialise()
tube.geometry (1/10) 

time = 0

# %%
while True:
    speed, density = tube.evolve()
    if time%100 == 0:
        print("Iteration %d, elapsed time %.3f, speed = %.3e" % (time, Karman.report_time (), time/Karman.report_time()))
    if time%numSnap == 0: 
        fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True,  figsize=(40, 20))
        plt.subplot(121)
        plt.imshow(speed.transpose(), cmap=cm.hot)
        
        plt.subplot(122)
        plt.imshow(density.transpose(), cmap=cm.cool)
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title("Cylindrical with constriction, Re = %.3f, iteration %d" % (Karman.reynolds, time))
        plt.show()
        plt.close()
    time += 1
# Out:
# Iteration 0, elapsed time 42.851, speed = 0.000e+00
# Iteration 100, elapsed time 43.371, speed = 2.306e+00
# Iteration 200, elapsed time 43.949, speed = 4.551e+00
# Iteration 300, elapsed time 44.522, speed = 6.738e+00
# Iteration 400, elapsed time 45.109, speed = 8.868e+00
# Iteration 500, elapsed time 45.646, speed = 1.095e+01
# Iteration 600, elapsed time 46.189, speed = 1.299e+01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-afddd2509302> in <module>()
#       9
#      10         plt.subplot(122)
# ---> 11         plt.imshow(density.transpose(), cmap=cm.cool)
#      12         plt.xlabel("x")
#      13         plt.ylabel("y")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3099                         filternorm=filternorm, filterrad=filterrad,
#    3100                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3101                         **kwargs)
#    3102     finally:
#    3103         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5133         if im.get_clip_path() is None:
#    5134             # image does not already have clipping set, clip to axes patch
# -> 5135             im.set_clip_path(self.patch)
#    5136         #if norm is None and shape is None:
#    5137         #    im.set_clim(vmin, vmax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     679             if isinstance(path, Rectangle):
#     680                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 681                                                path.get_transform())
#     682                 self._clippath = None
#     683                 success = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     189         to the :class:`Patch`.
#     190         """
# --> 191         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     192
#     193     def get_data_transform(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     690
#     691     def get_patch_transform(self):
# --> 692         self._update_patch_transform()
#     693         return self._rect_transform
#     694
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     685         bbox = transforms.Bbox.from_bounds(x, y, width, height)
#     686         rot_trans = transforms.Affine2D()
# --> 687         rot_trans.rotate_deg_around(x, y, self.angle)
#     688         self._rect_transform = transforms.BboxTransformTo(bbox)
#     689         self._rect_transform += rot_trans
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    2040         # Cast to float to avoid wraparound issues with uint8's
#    2041         x, y = float(x), float(y)
# -> 2042         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    2043
#    2044     def translate(self, tx, ty):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\transforms.py in translate(self, tx, ty)
#    2052         translate_mtx = np.array(
#    2053             [[1.0, 0.0, tx], [0.0, 1.0, ty], [0.0, 0.0, 1.0]], float)
# -> 2054         self._mtx = np.dot(translate_mtx, self._mtx)
#    2055         self.invalidate()
#    2056         return self
#
# KeyboardInterrupt:

# %% [markdown]
#  <h2> Context </h2>
#  <p> Some information can be found <a href="">here</a>.</p>
