# %%
import numpy as np
from tube_constriction import tubeConstriction
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.animation import FuncAnimation
from numba import jit

# %%
re = 500

numSteps = 250000
numSnap = 100;

# %%
 
width = int(1000)
height = int(200)

# %%
tube = tubeConstriction(re, width, height, height/9)

tube.initialise() 
tube.geometry (3/10, 40, 40) 
 
time = 0

# %%
while True:
    speed, density = tube.evolve()
    if time%100 == 0:
        print("Iteration %d, elapsed time %.3f, speed = %.3e" % (time, tube.report_time (), time/tube.report_time()))
    if time%numSnap == 0: 
        fig, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=True,  figsize=(40, 20))
        plt.subplot(121)
        plt.imshow(speed.transpose(), cmap=cm.hot)
        
        plt.subplot(122)
        plt.imshow(density.transpose(), cmap=cm.cool)
        plt.xlabel("x")
        plt.ylabel("y")
        plt.title("Cylindrical with constriction, Re = %.3f, iteration %d" % (tube.reynolds, time))
        plt.show()
        plt.close()
    time += 1
    
    if time>numSteps and time%numSnap == 0:
        break
# Out:
# Iteration 0, elapsed time 2.643, speed = 0.000e+00
# Iteration 100, elapsed time 15.929, speed = 6.278e+00
# Iteration 200, elapsed time 29.130, speed = 6.866e+00
# Iteration 300, elapsed time 42.280, speed = 7.096e+00
# Iteration 400, elapsed time 55.662, speed = 7.186e+00
# Iteration 500, elapsed time 69.294, speed = 7.216e+00
# Iteration 600, elapsed time 83.306, speed = 7.202e+00
# Iteration 700, elapsed time 96.848, speed = 7.228e+00
# Iteration 800, elapsed time 109.135, speed = 7.330e+00
# Iteration 900, elapsed time 121.188, speed = 7.427e+00
# Iteration 1000, elapsed time 133.990, speed = 7.463e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c044f6128b78> in <module>()
#       1 while True:
# ----> 2     speed, density = tube.evolve()
#       3     if time%100 == 0:
#       4         print("Iteration %d, elapsed time %.3f, speed = %.3e" % (time, tube.report_time (), time/tube.report_time()))
#       5     if time%numSnap == 0:
#
# ~\Documents\UL\Repos\LatticeBoltzmannD2Q9\latticeboltzmann.py in evolve(self)
#     137
#     138         #Stream
# --> 139         self.distributions = self.stream(new_distributions)
#     140
#     141
#
# ~\Documents\UL\Repos\LatticeBoltzmannD2Q9\latticeboltzmann.py in stream(self, new_distributions)
#     144         return speed, density
#     145     def stream(self, new_distributions):
# --> 146         return numba_roll(new_distributions, self.basis_velocity)
#     147     def collide(self, density_equilibrium):
#     148         """ Collision step relaxation"""
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\numeric.py in roll(a, shift, axis)
#    1391         for indices in itertools.product(*rolls):
#    1392             arr_index, res_index = zip(*indices)
# -> 1393             result[res_index] = a[arr_index]
#    1394
#    1395         return result
#
# KeyboardInterrupt:

# %% [markdown]
#  <h2> Context </h2>
#  <p> Some information can be found <a href="">here</a>.</p>
